# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.ticker import AutoMinorLocator
from mayavi import mlab
from tvtk.tools import visual
from scipy import interpolate
import math
from numpy import unravel_index
import pickle
from datalib import Data
from mayavi import mlab
from scipy.interpolate import RegularGridInterpolator
from scipy.interpolate import griddata
import healpy as hp
from mpl_toolkits.mplot3d import Axes3D

# %%
dir = 'Data/Dipole/'
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view54_abr.txt",unpack=True)
ax.scatter(v1,v2,label="height=0.1R")
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view54_abr.txt",unpack=True)
ax.scatter(v1,v2,label="height=1R")
v1,v2 = np.genfromtxt(dir+"PA_rem3_h10_view54_abr.txt",unpack=True)
ax.scatter(v1,v2,label="height=10R")
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("r_em=3R, view=54 deg",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_dip_height_3R.png",bbox_inches='tight')
plt.show()

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view54_abr.txt",unpack=True)
ax.scatter(v1,v2, label="view=54 deg")
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view65_abr.txt",unpack=True)
ax.scatter(v1,v2,label="view=65 deg")
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view75_abr.txt",unpack=True)
ax.scatter(v1,v2,label="view=75 deg")
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("r_em=3R, height=1R",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_dip_3R_view.png",bbox_inches='tight')
plt.show()

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view65_abr.txt",unpack=True)
ax.scatter(v1,v2, label="Aberration = True")
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view65_noabr.txt",unpack=True)
ax.scatter(v1,v2,label="Aberration = False")
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("r_em=3R, Height=1R, view=65 deg",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_dip_aberr.png",bbox_inches='tight')
plt.show()

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view54_abr.txt",unpack=True)
ax.scatter(v1,v2, label="r_em=3R")
v1,v2 = np.genfromtxt(dir+"PA_rem7_h01_view54_abr.txt",unpack=True)
ax.scatter(v1,v2,label="r_em=7R")
v1,v2 = np.genfromtxt(dir+"PA_rem12_h01_view54_abr.txt",unpack=True)
ax.scatter(v1,v2,label="r_em=12R")
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("height=0.1R, view=54 deg",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_dip_diff_rem.png",bbox_inches='tight')
plt.show()

# %%
dir = 'Data/Multipole/'

# %%
def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2, label="view=54 deg",alpha=0.5)
ax.plot(v1,smooth(v2,10), lw=2.5, c='b')
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view65_abr_mult.txt",unpack=True)
ax.scatter(v1,v2,label="view=65 deg",alpha=0.5)
ax.plot(v1,smooth(v2,10), lw=2.0, c='r')
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view75_abr_mult.txt",unpack=True)
ax.scatter(v1,v2,label="view=75 deg",alpha=0.5)
ax.plot(v1,smooth(v2,10), lw=2.0, c='g')
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("r_em=3R, height=0.1R",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
#plt.savefig(dir+"PA_dip_3R_view.png",bbox_inches='tight')
plt.show()

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2, label="r_em=3R",alpha=0.5)
#ax.plot(v1,smooth(v2,10), lw=2.5, c='b')
v1,v2 = np.genfromtxt(dir+"PA_rem5_h01_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2,label="r_em=5R",alpha=0.5)
#ax.plot(v1,smooth(v2,10), lw=2.0, c='r')
v1,v2 = np.genfromtxt(dir+"PA_rem7_h01_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2,label="r_em=7R",alpha=0.5)
#ax.plot(v1,smooth(v2,10), lw=2.0, c='g')
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("view=54 deg, height=0.1R",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_mult_rem.png",bbox_inches='tight')
plt.show()

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2, label="height=1R",alpha=0.5)
ax.plot(v1,smooth(v2,4), lw=2.5, c='b')
v1,v2 = np.genfromtxt(dir+"PA_rem3_h10_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2,label="height=10R",alpha=0.5)
ax.plot(v1,smooth(v2,4), lw=2.0, c='r')
v1,v2 = np.genfromtxt(dir+"PA_rem3_h14_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2,label="height=14R",alpha=0.5)
ax.plot(v1,smooth(v2,4), lw=2.0, c='g')
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("view=54 deg, r_em=3R",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
#plt.savefig(dir+"PA_dip_3R_view.png",bbox_inches='tight')
plt.show()

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem14_h1_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2, label="h=1R, r_em=14R",alpha=0.8)
#ax.plot(v1,smooth(v2,20), lw=2.0, c='b')
v1,v2 = np.genfromtxt(dir+"PA_rem3_h14_view54_abr_mult.txt",unpack=True)
ax.scatter(v1,v2,label="h=14R, r_em=3R",alpha=0.8)
#ax.plot(v1,smooth(v2,10), lw=2.0, c='r')
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("view=54 deg",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_mult_h_rem.png",bbox_inches='tight')
plt.show()

# %%
dir = 'Data/ForceFree/'

# %%
def rescale_y(y):
    ids = np.where(v2>65)[0]
    v2[ids] = v2[ids]-180
    return v2

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view54_abr_multFF.txt",unpack=True)
ax.scatter(v1,rescale_y(v2), label="height=0.1R",alpha=0.8)
ax.plot(v1,smooth(v2,3), lw=2.5, c='b')
v1,v2 = np.genfromtxt(dir+"PA_rem3_h1_view54_abr_multFF.txt",unpack=True)
ax.scatter(v1,rescale_y(v2),label="height=1R",alpha=0.8)
#ax.plot(v1[1:],smooth(v2[1:],15), lw=2.0, c='r')
v1,v2 = np.genfromtxt(dir+"PA_rem3_h5_view54_abr_multFF.txt",unpack=True)
ax.scatter(v1,rescale_y(v2),label="height=5R",alpha=0.8)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h10_view54_abr_multFF.txt",unpack=True)
ax.scatter(v1,rescale_y(v2),label="height=10R",alpha=0.8)
#ax.plot(v1,smooth(v2,15), lw=2.0, c='g')
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("view=54 deg, r_em=3R",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
ax.set_xlim(-90,90)
ax.set_ylim(-150,90)
plt.savefig(dir+"PA_FF_3R_height.png",bbox_inches='tight')
plt.show()

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem3_h01_view54_abr_multFF.txt",unpack=True)
ax.scatter(v1,v2, label="r_em=3R",alpha=0.8)
ax.plot(v1,smooth(v2,3), lw=2.5, c='b')
v1,v2 = np.genfromtxt(dir+"PA_rem6_h01_view54_abr_multFF.txt",unpack=True)
ax.scatter(v1,smooth(rescale_y(v2),1),label="r_em=6R",alpha=0.8)
v1,v2 = np.genfromtxt(dir+"PA_rem10_h01_view54_abr_multFF.txt",unpack=True)
ax.scatter(v1,rescale_y(v2),label="r_em=10R",alpha=0.8)
#ax.plot(v1,smooth(v2,2), lw=2.0, c='r')
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_title("view=54 deg, height=0.1R",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_FF_rem.png",bbox_inches='tight')
plt.show()

# %%
from matplotlib.collections import PathCollection
from matplotlib.legend_handler import HandlerPathCollection, HandlerLine2D

def update(handle, orig):
    handle.update_from(orig)
    handle.set_alpha(1)

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
ini_ph = 0.05*210%(2*np.pi)*180/np.pi
plt.ylim(0,180)
plt.xlim(-180,180)
x_em_points, y_em_points, z_em_points = np.genfromtxt("open_field_lines_rem_3_high.txt",unpack=True)
rr = np.sqrt(x_em_points**2+y_em_points**2+z_em_points**2)
th_points = np.arccos(z_em_points/rr)
phi_points = np.arctan2(y_em_points,x_em_points)
ax.scatter((phi_points*180/np.pi),th_points*180/np.pi,s=1, alpha=0.4, label="r_em=3R")
x_em_points, y_em_points, z_em_points = np.genfromtxt("open_field_lines_rem_6_high.txt",unpack=True)
rr = np.sqrt(x_em_points**2+y_em_points**2+z_em_points**2)
th_points = np.arccos(z_em_points/rr)
phi_points = np.arctan2(y_em_points,x_em_points)
ax.scatter((phi_points*180/np.pi),th_points*180/np.pi,s=1, alpha=0.4, label="r_em=6R")
x_em_points, y_em_points, z_em_points = np.genfromtxt("open_field_lines_rem_10_high.txt",unpack=True)
rr = np.sqrt(x_em_points**2+y_em_points**2+z_em_points**2)
th_points = np.arccos(z_em_points/rr)
phi_points = np.arctan2(y_em_points,x_em_points)
ax.scatter((phi_points*180/np.pi),th_points*180/np.pi,s=1, alpha=0.4, label="r_em=10R")
x_em_points, y_em_points, z_em_points = np.genfromtxt("open_field_lines_rem_2_high.txt",unpack=True)
rr = np.sqrt(x_em_points**2+y_em_points**2+z_em_points**2)
th_points = np.arccos(z_em_points/rr)
phi_points = np.arctan2(y_em_points,x_em_points)
ax.scatter((phi_points*180/np.pi),th_points*180/np.pi,s=1, alpha=0.4,label="r_em=2R")
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'$\theta$ [deg]',size=18)
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
#ax.legend(loc="best",fontsize=14,ncol=1)
#plt.legend(handler_map={PathCollection : HandlerPathCollection(update_func= update),
#                        plt.Line2D : HandlerLine2D(update_func = update)}, fontsize=20)
plt.legend(loc="lower left", markerscale=10., scatterpoints=1, fontsize=13, ncol=4)
plt.savefig("poles_shape.png",bbox_inches='tight')

# %%
import pandas as pd
def smoothen(x, winsize=2):
    return np.array(pd.Series(x).rolling(winsize).mean())[winsize-1:]

# %%
from scipy.interpolate import interp1d

# %%
f = plt.figure(figsize=(9,7))
ax = f.add_subplot(111)
v1,v2 = np.genfromtxt(dir+"PA_rem5_h01_view54_abr_multFF.txt",unpack=True)
ids1 = np.where(np.logical_and(v1>-100,v1<100))[0]
v1 = v1[ids1]
v2 = v2[ids1]
ids2 = np.where(np.logical_and(v2>-40,v2<80))[0]
v1 = v1[ids2]
v2 = v2[ids2]
ax.scatter(v1,v2, label="r_em=5R",marker="o",s=20,c="k")
f = interp1d(v1, v2, kind='cubic')
v11 = np.linspace(min(v1),max(v1),50)
#ax.scatter(v11,f(v11))
ax.set_xlabel(r'$\phi$[deg]',size=18)
ax.set_ylabel(r'P.A. ($\Psi$ [deg])',size=18)
ax.legend(loc="best",fontsize=14,ncol=1)
ax.set_ylim(-60,120)
ax.set_xlim(-150,150)
ax.set_title("view=54 deg, height=0.1R",fontsize=16)
ax.xaxis.set_minor_locator(AutoMinorLocator())
ax.yaxis.set_minor_locator(AutoMinorLocator())
ax.tick_params(axis='both', which='major', direction='in',length=8, width=1., colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='both', which='minor', direction='in',length=4, width=1, colors='k', left=True, right=True, top=True, pad=8)
ax.tick_params(axis='x', labelsize=16)
ax.tick_params(axis='y', labelsize=16)
plt.savefig(dir+"PA_FF_rem5.png",bbox_inches='tight')
plt.show()
